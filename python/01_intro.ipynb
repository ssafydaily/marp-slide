# %%
age = 20
height = 175.5
name = '홍길동'

print(type(10), type(age))
print(type(3.14), type(height))
print(type('누구세요?'), type(name))
# Out:
# <class 'int'> <class 'int'>
# <class 'float'> <class 'float'>
# <class 'str'> <class 'str'>
